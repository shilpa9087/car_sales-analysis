# %% [markdown]
# # **Python for Data Science**
# # **Project - Austo Automobile Data Analysis**

# %% [markdown]
# ## Context
#
# Austo Motor Company is a leading car manufacturer specializing in SUV, Sedan and Hatchback models. In its recent board meeting, concerns were raised by the members on the efficiency of the marketing campaign currently being used. The board decides to rope in an analytics professional to improve the existing campaign.
#
# ## Objective
#
# They want to analyze the data to get a fair idea about the demand of customers which will help them in enhancing their customer experience. Suppose you are a Data Scientist at the company and the Data Scientist at the company and the Data Science team has shared some of the key questions that need to be answered. Perform the data analysis to find answers to these questions that will help the company to improve the business.
#
# ## data Description
#
#
# * Age: The age of the individual in years.
# * Gender: The gender of the individual, categorized as male or female.
# * Profession: The occupation or profession of the individual.
# * Marital_status: The marital status of the individual, such as married and single.
# * Education: The educational qualification of the individual Graduate and Post Graduate.
# * No_of_Dependents: The number of dependents (e.g., children, elderly parents) that the individual supports financially.
# * Personal_loan: A binary variable indicating whether the individual has taken a housing loan 'yes' or 'no'
# * House_Loan: A binary variable indicating whether the individual has taken a housing loan 'yes' or 'no'
# * Partner_working: A binary variable indicating whether the individual's partner is employed 'yes' or 'no'
# * Salary: The individual's salary or income.
# * Partner_salary: The salary or income of the individual's partner, if applicable.
# * Total_salary: The total combined salary of the individual and their partner (if applicable).
# * Price: The price of a product or service.
# * Make: The type of automobile.

# %% [markdown]
# **Import the libraries which is necessary for data analysis.**

# %%
# import the necessary libraries for data manipulation and observation
import numpy as np
import pandas as pd

# import the necessary libraries for the data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import the data set
df = pd.read_csv("C:\\Users\\Dell\\Downloads\\austo_automobile+%282%29+%281%29.csv")

# %% [markdown]
# * Imort the data and for convenience first 5 rows are displayed.

# %%
df.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
df.shape
# Out:
# (1581, 14)

# %% [markdown]
# * To understand the given data, we need to know about the each column and rows and the given data has 1581 columns and 14 rows.

# %%
# structure and type of the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %% [markdown]
# * Six integer data type and Eight Numerical data type columns are there.
# * The Gender column and Partner_salary column contains null values.
#
# Check how many number of unique data set is there in each column.

# %%
df.nunique()
# Out:
# Age                  33
# Gender                4
# Profession            2
# Marital_status        2
# Education             2
# No_of_Dependents      5
# Personal_loan         2
# House_loan            2
# Partner_working       2
# Salary              538
# Partner_salary      149
# Total_salary        754
# Price                53
# Make                  3
# dtype: int64

# %%
# Statistical summary of the data
df.describe(include='all').T
# Out:
#                    count unique            top  freq          mean  \
# Age               1581.0    NaN            NaN   NaN     31.922201
# Gender              1528      4           Male  1199           NaN
# Profession          1581      2       Salaried   896           NaN
# Marital_status      1581      2        Married  1443           NaN
# Education           1581      2  Post Graduate   985           NaN
# No_of_Dependents  1581.0    NaN            NaN   NaN      2.457938
# Personal_loan       1581      2            Yes   792           NaN
# House_loan          1581      2             No  1054           NaN
# Partner_working     1581      2            Yes   868           NaN
# Salary            1581.0    NaN            NaN   NaN  60392.220114
# Partner_salary    1475.0    NaN            NaN   NaN  20225.559322
# Total_salary      1581.0    NaN            NaN   NaN  79625.996205
# Price             1581.0    NaN            NaN   NaN   35597.72296
# ...

# %% [markdown]
# The above table shows the Statistical summery of the data. It can be observes the average(mean) value, minimum value, maximum value, and other parameter of the each column.
# * There is maximum 4 people dependes on each working person, minimum no people and average is 2 people depend on each working person.
# * The average salary of the person is nearly 60,000 then maximum and minimum salary of the person is 99,300 and 30,000 respectively.

# %%
# checking the missing value across each columns
df.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %% [markdown]
# Here Gender column has 53 'missing' or 'Nan' values and same way Partner_salary colum has 106 'missing' or 'nan' values.
# In order to change from nan to some useful data we need to do missing value treatment.
# In Gender column replace the variable 'nan' to 'unknown'.

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Femal', 'Female', nan, 'Femle'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: Gender, dtype: int64

# %%
# Replaceing the nan with Unknown 
df['Gender'].fillna('Unknown', inplace=True)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Femal', 'Female', 'Unknown', 'Femle'], dtype=object)

# %% [markdown]
# * The 'Femal' and 'Femle' are replaced to 'Female', because it may be spelling mistake.

# %%
df['Gender'].replace('Femal','Female',inplace=True)

# %%
df['Gender'].replace('Femle','Female',inplace=True)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Partner_salary'].value_counts(normalize=True)
# Out:
# 0.0        0.422373
# 40500.0    0.019661
# 40200.0    0.018305
# 40100.0    0.016949
# 40000.0    0.016949
#              ...
# 45800.0    0.000678
# 27300.0    0.000678
# 22900.0    0.000678
# 23100.0    0.000678
# 35000.0    0.000678
# Name: Partner_salary, Length: 149, dtype: float64

# %%
df['Partner_salary'].unique()
# Out:
# array([70700., 70300., 60700., 60200., 60500., 50800., 40400.,     0.,
#        70600., 60600., 60300., 45500., 40200., 40700.,   600.,   700.,
#        27800., 70000., 40100., 40900., 27000.,    nan, 40500., 50400.,
#        80400., 60900., 60100., 70200., 30000., 40300., 40800., 70800.,
#          900., 45000., 40600., 50700., 80500., 27700., 35800., 26600.,
#        60000., 27900., 60800., 40000., 70100., 38100., 38200., 30200.,
#        38500., 50900., 35100., 38700., 38300., 38900., 23200., 24700.,
#        30800., 28100., 38400., 38000., 23100., 30100., 25700., 70400.,
#          200., 30900., 26100., 45700.,   400., 28200., 70900., 38800.,
#        45200., 26800., 60400., 30300., 25800.,   800., 38600., 24500.,
#        30700., 28500., 24900., 70500., 35900., 30500., 28900., 27200.,
#        45900., 25300., 35600., 25000., 25200., 26300., 35700., 23800.,
#        32700., 30600., 45600., 28000., 32600., 28600., 25100., 26700.,
# ...

# %%
df['Partner_salary'] = df['Partner_salary'].fillna(value=df['Partner_salary'].mean())

# %% [markdown]
# * THe partner_salary column has some missed value, and is treated has using mean.

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate analysis

# %%
# Histogram for age with kde
plt.title('Age distribution with kde')
plt.xlabel('Age')
plt.ylabel('Frequence')
sns.histplot(data=df, x='Age', kde=True)
plt.show()

# Boxplot for age
plt.title('Boxplot of Age')
plt.xlabel('Age')
sns.boxplot(data=df, x='Age')
plt.show()

# %% [markdown]
# The histogram with kde (Kernal Density Estimation) provides a visual representation of the distribution of the 'Age' variable.
#
# * The histogram shows how ages are distributed across the dataset. It allows us to see the frequency of different age groups.
# * The smooth line overlaying the histogram (kde) heps in understanding the density of data points. Peakes in the kde line indicate age ranges with higher in concentrations of individuals.
#
# The boxplot provides a summery of the distribution of 'Age' variable, highlighting key statistical measures and potential outliers.
#
# * The line inside the box represents the **Median** age, which is the middle value of the data set. here the middle value of the data set is 29 Years.
# * The age distribution from the above plot is positively skewed. There is no outliers in the age distribution.

# %%
plt.title('Distribution of Number of Dependents')
plt.xlabel('Number of Dependents')
sns.countplot(df, x='No_of_Dependents')
plt.show()

# %% [markdown]
# * The above plot shows how many individuals have 0, 1, 2, 3, or 4 dependents. By looking at the height of the bars, we can quickly see which categories are more or less common.
# * The tallest bar indicates the most common number of dependents. The bar 2 and 3 dependent is tallest, it means that most individuals in the dataset have 2 and 3 dependent.
# * The shortest bar indicates the least common number of dependents. The bar 0 dependent is shortest, it means very few individuals don't have dependents.

# %%
# Histogram for salary
plt.title('Salary Distribution')
sns.histplot(df, x='Salary')
plt.show()

# Boxplot for salary
plt.title('Boxplot of salary')
sns.boxplot(df, x='Salary')
plt.show()

# %% [markdown]
# * The x-axis represents salary amounts ranging from \\$30,000 to \\$100,000. The y-axis shows the frequency of individuals falling into different salary ranges.
# * The histogram shows a distribution that is roughly symmetrical with slight right skew. this indicates that while most individuals earn salaries around the central peak, there are fewer individuals earning higher salaries.
# * The most salaries falling between \\$40,000 and \\$80,000.

# %%
# Histogram for partner salary
plt.title('Partner Salary Distribution')
plt.xlabel('Partner Salary')
sns.histplot(df, x='Partner_salary')
plt.show()

# Boxplot for partner salary
plt.title('Boxplot for Partner Salary')
plt.xlabel('Partner Salary')
sns.boxplot(df, x='Partner_salary')
plt.show()

# %% [markdown]
# * The significant number of partners, over 600, have a salary of \\$0, indicates either they are unemployed, homeworkers or have no reported income.
# * The mejority of partner salaries cluster between \\$20,000 and \\$40,000, with noticeable peaks around \\$30,000 and \\$40,000.
# * There are very few partners earning above \\$50,000, suggesting that high partner salaries are less common here.
# * The median partner salary will be around the \\$25,000 indicating the midpoint of the data.
# * The IQR, spanning from the first quartile (Q1) to the third quartile (Q3), will likely range from around \\$0 to \\$40,000, showing where the middle 50% salaries lie.

# %%
# Histogram for total salary
plt.title('Total Salary Distribution')
plt.xlabel('Total Salary')
sns.histplot(df, x='Total_salary')
plt.show()

# Boxplot for total salary
plt.title('Boxplot for Total Salary')
plt.xlabel('Total Salary')
sns.boxplot(df, x='Total_salary')
plt.show()

# %% [markdown]
# * The histogram shows that the majority of individuals have total salaries ranging between \\$50,000 and \\$100,000 with a noticeable peak around the \\$60,000 to \\$80,000 range.
# * The distribution is right skewed, indicating that while most salaries cluster arond the lower end, there are a few individuals with significantly higher salaries, extending upto \\$160,000.
# * The boxplot complements the histogram by visually summarizing the distribution, highlighting the median salary which is around \\$80,000.
# * The interquartile range (IQR), which spans from the first quartile (approximately $60,000) to the third quartile (approximately \\$90,000), shows where the middle 50% of the data lies.
# * Outliers are present beyond the upper whisker (around \\$120,000), indicating those individuals who earn significantly more than rest of the population.

# %%
# Histogram for price
plt.title('Price Distribution')
plt.xlabel('Price')
sns.histplot(df, x='Price')
plt.show()

# Boxplot for price
plt.title('Boxplot for Price')
plt.xlabel('Price')
sns.boxplot(df, x='Price')
plt.show()

# %% [markdown]
# * The histogram shows the count of cars across the various price ranges. The majority of cars are priced between \\$20,000 and \\$30,000.
# * There is a noticeble decline in the number of cars as the price increases beyond \\$30,000. Very few cars are priced above \\$60,000, indicates luxury models are less common.
# * Similarly, the bo plot provides a summery of the price distribution with key statistical measures.
# * The median price is approximately \\$30,000, indicating that half of the cars are priced below this value. The IQR spans from nearly \\$25,000 to \\$45,000, shows the where the middle 50% of car prices lie. And the distribution is right-skewed.

# %% [markdown]
# ### Explore all the categorical columns

# %%
plt.title('Distribution of Gender')
plt.xlabel('Gender')
sns.countplot(data=df, x='Gender')
plt.show()

# %% [markdown]
# The above bar graph shows, The data contain more male individuals compare to female individuals.

# %%
plt.title('Distribution of Profession')
plt.xlabel('Profession')
sns.countplot(df, x='Profession')
plt.show()

# %% [markdown]
# * From above graph, the data contain more Salaried individuals compare to Business individual.

# %%
plt.title('Distribution of Marital Status')
plt.xlabel('Marital Status')
sns.countplot(df, x='Marital_status')
plt.show()

# %% [markdown]
# * From the above graph, it shows that data contain nearly 90% of people are marrid and only 10% of poeple are unmaried.

# %%
plt.title('Distribution of Education')
plt.xlabel('Education')
sns.countplot(df, x='Education')
plt.show()

# %% [markdown]
# * Eduction of the individual is distributed, The postgraduated people are higher compare to the Graduated people.

# %%
plt.title('Distribution of Partner Working')
plt.xlabel('Partner Working')
sns.countplot(df, x='Partner_working')
plt.show()

# %% [markdown]
# * The number of working partners are high compared to the non working partners.

# %%
plt.title('Distribution of Personal Loan')
plt.xlabel('Personal Loan')
sns.countplot(df, x='Personal_loan')
plt.show()

# %% [markdown]
# * This graph shows that personal loan uptake is evenly distributed among the customer base.
# * This indicates that personal loan uptake is evenly distributed among the customer base. There is no significant difference in the number of customers who have taken a personal loan versus those who have not.

# %%
plt.title('Distribution of House Loan')
plt.xlabel('House Loan')
sns.countplot(df, x='House_loan')
plt.show()

# %% [markdown]
# * The above graph shows, the mejority of individuals in the dataset do not have a house loan.

# %%
plt.title('Distribution of Make')
plt.xlabel('Make')
sns.countplot(df, x='Make')
plt.show()

# %% [markdown]
# * From the above graph, the Sedan car sales more compare to Hatchback and SUV and the SUV's sale is very low.

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# **Explain the relationship between Numerical Variables**

# %%
sns.pairplot(data=df[['Age','No_of_Dependents','Salary','Partner_salary','Total_salary','Price']])
plt.show()

# %% [markdown]
# To explain the relationship between the numerical variables shown in the pair plot, we can analyze each scatter plot and the distribution of each variable.
# * **Age v/s Number of dependents:** The scatter plot shows no clear linear relationship between age and the number of dependents. The number of dependents seems to be fairly distributed across different age groups, with a few distinct categories of dependents.
# * **Age V/s salary:** There is a positive correlation between age and salary. As age increases, salary tends to increase as well. However, the relationship is not perfectly linear, it has some variability.
# * **Age v/s Partner salary:**  There is a weak positive correlation between age and partner salary. Partner salary shows an increasing trend with age but with significant spread.
# * **Age v/s Total salary:** There is a noticeable positive correlation between age and total salary. As age increases, total salary also tends to increase, showing a stronger correlation than with individual salaries.
# * **Age v/s Price:** The scatter plot shows that price does not have a clear relationship with age. Prices seem to be spread across different age groups without a strong pattern.
# * **Number of dependents v/s Salary:** The scatterplot shows a weak relationship between the number of dependentsand salary. Salaries are distributed across different numbers of dependents, with no clear trned.
# * **Number of dependents v/s Partner salary:** It is similar to the relationship between the number of dependents and partner salary. The data points are scattered without a clear pattern.
# * **Number of dependents v/s Total salary:** The scatter plot shows no clear relationship between the number of dependents and total salary. Total salaries are distributed across different numbers of dependents.
# * **Number of dependents v/s Pice:** There is no obvious relationship between the number of dependents and Price. Prices are spread across different numbers of dependents.
# * **Salary v/s Partner Salary:** There is weak positive correlation between Salary and Partner salary. Higher salaries tend to be associated with higher partner salaries, through the relationship is not strong.
# * **Salary v/s Total salary:** There is a strong positive correlation between salary and total salary, as expected. Total salary increases with the individual's salary.
# * **Salary v/s Price:** There is a weak positive correlation between salary and price. Higher salaries are somewhat associated with higher prices, but the relationship is not strong.
# * **Partner salary v/s Total salary:** There is a strong positive correlation between partner salary and total salary, similar to the individual's salary. Total salary increases with partner salary.
# * **Partner salary v/s Price:** There is no strong relation between partner salary and price. Prices are spread across different partner salaries.
# * **Total salary v/s Price:** There is a positive relationship between total salary and price. Higher total salaries tend to be a associated with  higher prices, indicating that households with higher combined incomes tend to afford higher prices.
#
# 1. There is a strong positive correlation between individual salaries, partner salaries, and Total salaries.
# 2. The number of dependents does not show a strong correlation with any of the numerical variables. Age shows a weak positive correlation with salary and total salary.
# 3. Price shows a Weak positive relationship with total salary but no strong relationship with other variables.

# %% [markdown]
# **Explain the relationship between categorical and numerical variables**

# %%
plt.title('violin plot for Total salary with profession')
sns.violinplot(data=df, x='Profession', y='Total_salary')
plt.show()

# %% [markdown]
# * The violin plot illustrate the relationship between the categorical variable 'Profession' (with categories 'Business' and 'Salaried') and the numerical variable Total salary.
# * Both Business and Salaried professions exhibit a similar overall shape, indicating the spread and density of salaries.
# * The white dot i each violin plot represents the median salary. The median salary for both professions appears to be similar, suggesting no significant difference in the central salary value.
# * The thick black bae in the central of each violin represents the IQR, showing the middle 50% of the data. Both categories have a similar IQR, indicating comparable variability in salaries.
#
# Overall, the violin plot reveals that there is no significant difference in the salary distribution between business and salaried professions, with both categories showing similar central tendencies, variability, and ranges.

# %%
plt.title('Distribution for Price and Make')
sns.boxplot(data=df, x='Make', y='Price')
plt.show()

# %% [markdown]
# * The box plot shows the distribution of car prices across three different car types (Make): SUV, Sedan, and Hatchback.
# * The median price is highest for SUVs, followed by Sedans, and lowest for Hatchbacks.
# * SUVs have the widest price range,followed by Sedans with Hatchbacks having the narrowest range.
# * The IQR, represented by the heightof the box, is largest for SUVs, indicating more variability in their prices. Sedan have a moderate IQR, and Hatchbacks have the smallest IQR.
# * The whiskers show the spread of the prices. SUVs have a few outliers below the lower whisker, indicating some unusually low priced SUV's.
# * SUVs are generally more expansive with a broader price range, whereas Hatchbacks are the least expansive and have the most consistent pricing.
# * The spread of the data points, represented by the length of the whiskers and the height of the boxes) shows how pricing vary within each car type.

# %% [markdown]
# **Let's check do men tend to prefer SUVs more compared to women**

# %%
# Preference for SUVs by gender.
suv_preference = df[df['Make'] == 'SUV']['Gender'].value_counts(normalize=True)

# Visualizing SUV preference by gender
plt.title('SUV Preference by Gender')
sns.countplot(x='Gender', data=df[df['Make'] == 'SUV'])
plt.show()

# %% [markdown]
# * The above plot illustrates the count of SUV preferences catagorized by gender. The x-axis shows three gender categories: Male, Female and unknown. The chart reveals that females have the highest preferences for SUVs compare to Males and unknown. The preference among individuals with unknown gender is very low.

# %% [markdown]
# **Let's check what is the likelihood of a salaried person buying a Sedan**

# %%
# Likelihood of salaried individuals buying a sedan
sedan_buyers = df[df['Make'] == 'Sedan']
sedan_lIKelihood = sedan_buyers['Profession'].value_counts(normalize=True)

# Visualizing likelihood of salaried Individuals buying a sedan
plt.title('Likelihood of Salaried Individuals Buying a Sedan')
sns.countplot(data=sedan_buyers, x='Profession')
plt.show()

# %% [markdown]
# Based on the above graphical plot, it is evident that salaried individuals are more likely to purchase a Sedan comared to business people. The higher count of Sedan purchases among salaried individuals suggests a stroger preference or affordability for this car type within this graph. This trend could be attributed to the balance of cost, comfort and practicality that Sedan offer, which allign well with the needs of salaried individuals.

# %% [markdown]
# **Let's check Sheldon Cooper's claim on SUV sales to salaried males**

# %%
# Suv v/s sedan preference among salaried males
salaried_males = df[(df['Gender'] == 'Male') & (df['Profession'] == 'Salaried')]
suv_sedan_preference = salaried_males['Make'].value_counts(normalize=True)

# Visualizing SUV v/s Sedan preference among salaried males
plt.title('SUV v/s Sedan Preferences among Salaried Males')
sns.countplot(x='Make', data=salaried_males)
plt.show()

# %% [markdown]
#  The bar chart shows the preferences of salaried males among three car types: SUVs, Sedans, and Hatchbacks. The data reveals that Sedans are the most preferred, followed closely by Hatchbacks. The data reveals that Sedans are the most preferred, followed closely by Hatchbacks, while SUVs have significantly lower preference among others. This indicates that Sheldon Cooper's claim about high SUV sales to salaried males is not supported by the data. Instead, Sedans and Hatchbacks dominate the preferences of salaried males, with SUVs being the least popular choice.

# %% [markdown]
# **Let's check the amount spent on purchasing automobiles by gender**

# %%
# Amount spent by gender 
amount_spent_by_gender = df.groupby('Gender')['Price'].sum()

# Visualizing amount spent by gender
plt.title('Total Amount Spent on Automobiles by Gender')
sns.barplot(x=amount_spent_by_gender.index, y=amount_spent_by_gender.values)
plt.show()

# %% [markdown]
# From the chart it is evident that males have the highest total expenditure on automobiles, Females have spent significantly less. The Unknown gender category shows a minimal total expenditure, significantly lower than both males and females.

# %% [markdown]
# **Let's check the money spent by the individuals with a personal loan**

# %%
# Money spent by individuals with a personal loan
personal_loan_spending = df[df['Personal_loan'] == 'Yes']['Price'].sum()
personal_loan_spending
# Out:
# 27290000

# %% [markdown]
# Based on the data analysis, the total amount of money spent by individuals with a personal loan is \\$27,290,000. This significant expenditure highlights the financial leverage individuals are using through personal loans to afford these cars. This indicates that personal loans are a popular financing option for large purchases, possibly due to their accessibility and flexibility.

# %% [markdown]
# **Let's check the Influence of a working partner on purchase of higher-priced cars**

# %%
# Average price of cars bought by individuals with and without working partners
avg_price_partner = df.groupby('Partner_working')['Price'].mean()

# Visualising influence of working partner
plt.title('Influence of a Working Partner on Perchase of Higher-Priced Cars')
sns.barplot(x=avg_price_partner.index, y=avg_price_partner.values)
plt.show()

# %% [markdown]
# The influence of having a working partner on the purchase of higher-priced Cars appears to be minimal. Both groups show a high percentage of respondents not purchasing higher-priced cars, indicating that a working partner's status does not significantly impact this purchasing decision.

# %% [markdown]
# ## Actionable Insights and Recommendatios

# %% [markdown]
# ### Insights:
#
# * **Gender Preferences:** Women have a higher preference for SUVs compared to men.
# * **Sedan Likelihood:** Salaried individuals are more likely to purchase Sedan compared to Business people.
# * **SUV Targeting:** Shelden Cooper's claim is not supported; salaried males are not easier target for SUV sales over Sedan sales, instead they are easier target for Sedan sales.
# * **Spending by Gender:** Men tend to spend more on automobile purchases than women.
# * **Loan Impact:** Individuals with personal loans spend a significant amount on automobiles.
# * **Partner Influence:** Having a working partner or not, it does not influences the purchase of higher-priced Cars.
#
#
# ### Recomendation:
#
# * Position the Sedan brand as the smart choice for the modern professional, emphasizing aspects like sophistication, efficiency, and value for money. For SUVs, focus on branding that appeals to other demographic segment, such as safety, space, and off-road capabilities.
# * Strenghen the online presence for sedans through targeted digital marketing campaigns on platforms frequented by salaried males. Develop content that resonates with the target audience, such as blogs, videos, and testimonials that showcase the benifits of sedans.
# * Analyze competitors' stratergies for both Sedans and SUVs to identify successful tactics that could be adapted.
# * Reevaluate and adjust SUV marketing stratergies to target demographics more likely to purchase SUVs, such as families, adventure seekers, and those living in suburban or rural areas.
